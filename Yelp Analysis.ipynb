# %% [markdown]
# <h1>YELP REVIEW ANALYSIS</h1>

# %%
import math
import numpy as np
import pandas as pd
import datetime
from nltk import word_tokenize
from nltk import sent_tokenize
from collections import Counter

# %% [markdown]
# <h4> Pulling the data from the json files of Yelp academic data challenge<h4>
# <li> Business josn file contains information about the variuos businesses </li>
# <li> Review json file contains information about the reviews of these businesses </li>

# %%
import json
import datetime
datafile='business.json'
business_id = []
restaurant_name=[]
address=[]
city=[]
state=[]
star_rating=[]
review_count=[]
is_open=[]
attr = []
category=[]
lat=[]
long=[]
with open(datafile,'r') as f:
    for line in f:
        data = json.loads(line)
        if ('Restaurants' in data.get('categories')):
            business_id.append(data.get('business_id'))
            restaurant_name.append(data.get('name'))
            address.append(data.get('address'))
            city.append(data.get('city'))
            state.append(data.get('state'))
            star_rating.append(data.get('stars'))
            review_count.append(data.get('review_count'))
            is_open.append(data.get('is_open'))
            attr.append(data.get('attributes'))
            category.append(data.get('categories'))
            lat.append(data.get('latitude'))
            long.append(data.get('longitude'))

# %%
business=pd.DataFrame.from_items([('business_id',business_id),('lat',lat),('long',long),('business_name',restaurant_name),('address',address),('city',city),('state',state),('categories',category),('star_rating',star_rating),('is_open',is_open),('attr',attr)])

# %%
business
# Out:
#                   business_id        lat        long  \
# 0      mLwM-h2YhXl2NCgdS84_Bw  35.236870  -80.741976
# 1      duHFBe87uNSXImQmvBh87Q  33.505928 -112.038847
# 2      SDMRxmcKPNt1AHPBKqO64Q  35.135196  -80.714683
# 3      iFEiMJoEqyB9O8OUNSdLzA  35.355085  -81.087268
# 4      HmI9nhgOkrXlUr6KZGZZew  40.461350  -79.948113
# 5      qnpvw-uQyRn9nlClWFK9aA  43.639236  -79.716199
# 6      TXiEgINSZ75d3EtvLvkc4Q  43.128034  -89.307157
# 7      KW4y7uDGjVfU3ClkEjIGhg  43.834351  -79.090135
# 8      reWc1g65PNZnKz_Ub9QKOQ  43.841993  -79.429343
# 9      L1XHTn7S-6har9UGAPjcWQ  43.843475  -79.387686
# 10     PV9CdNFDOX4_zWm3Sy3W8g  43.097806  -89.519217
# 11     qim0lD112TkDhm8ZyQlRnA  43.678049  -79.314774
# 12     HRFJlSAP_EBU_MpPPmpUDQ  33.335058 -111.843076
# 13     FLTbKRmBytP1AbjWSPEeyw  33.318731 -111.943388
# 14     1AxEmgv8Dsr3iU9Aa40jPw  33.316278 -111.968018
# 15     Wf5C8Amv_SlhoYE3_W66WQ  43.763510  -79.490750
# 16     58APdML-PG_OD4El2ePTvw  45.499409  -73.555200
# 17     Z1r6b30Tg0n0ME4-Zj2wQQ  43.663010  -79.310898
# 18     -2q4dnUw0gGJniGW2aPamQ  40.094068  -88.245785
# 19     LDMCrFlGIFUN6L-FEFgzWg  36.196203 -115.116799
# 20     cBHMUESPj4SNs65Xv6xWRA  55.950268   -3.207114
# 21     QTH_XGh4rWYdd0fTW-tUDw  36.112519 -115.242605
# 22     01xXe2m_z048W5gcBFpoJA  33.478043 -111.986370
# 23     dEmNOTm8Rmm9JYZdGX_Lhw  45.497017  -73.581008
# 24     Bl7Y-ATTzXytQnCceg5k6w  41.726029  -81.240943
# 25     BvCHyg0GtxA6XKmRC0cQsg  43.560591  -79.576305
# 26     fl2TPNWrchkCbNEg0utjvw  40.133197  -88.198577
# 27     b5VIe-VnkOOwiwkjGw071A  55.934442   -3.105057
# 28     DiA78qPtp6rfRNdomzjBbw  36.083384 -115.033995
# 29     d2fkRF67jiASrXxHfbmJuA  33.319230 -111.874147
# ...                       ...        ...         ...
# 51583  kWDAdT4m3vbnmE0CgLs4gA  45.577508  -73.545944
# 51584  rofWaZTIuaedAxT_UKleSw  45.478815  -73.558896
# 51585  FUQLZ8nAnlXJKVpAA4wvzA  43.896377  -79.558142
# 51586  A7gVn077Eb2B-yIKunLVpw  33.407126 -111.873495
# 51587  jLTJw1Gm9Q9KG-iS2PWkpA  36.115273 -115.112276
# 51588  RwMLuOkImBIqqYj4SSKSPg  36.131594 -115.164767
# 51589  beb_QLcQySKwYFPyVu6eJw  40.484696  -79.815871
# 51590  wssONJTv6MEui3ShSzGzlw  43.833185  -79.266110
# 51591  ZyGpQ9k1D0c4xd8k7I_RXw  41.470029  -81.897178
# 51592  qbCPF1Z-Dher2MYUYFCX4Q  35.251733  -81.043172
# 51593  -0T0jfPnuBRdpNTXpOQZcA  43.908612  -79.268446
# 51594  ee8aiHC6zaY9JoLUVUSc1w  35.998540 -115.103376
# 51595  NZAxQxXH0YkSzPOKd_Nv-w  33.509667 -112.071740
# 51596  uytrX0s6etYPCcMVC07KJw  33.639496 -112.276363
# 51597  NPQE0JvwjmFca83ZuAXutQ  43.680709  -79.430740
# 51598  hgwkI7cx-ki7cWOSzzyTLw  36.100888 -115.079224
# 51599  mGUXzktXl1BlRdsVOy1WjA  36.070010 -115.082265
# 51600  Mkn4eaV7pVcat5PQ0U-4Qw  35.123349  -80.729626
# 51601  HUKbH7r9TBJPri6LJbBKtw  36.150021 -115.153717
# 51602  a8pmtlVKf7NiSLI-4KejIw  43.650741  -79.358017
# 51603  nKph91qATrPCbJ-QwZjDZw  36.086867 -115.100505
# 51604  Ee2d2D0pjQF4oExg9PQ5tQ  43.754927  -79.442695
# 51605  bYfEp3NMskYfEzWL8tVb4w  45.520289  -73.554658
# 51606  euUGjobp4ig838a0DE06bQ  33.456435 -112.394234
# 51607  Pb5AfEWAB8GWlHyy-p-l1g  33.600876 -112.287774
# 51608  7IQoE-EXnRCBUzaVHYlhmw  35.313384  -80.743157
# 51609  KcFfciiA1lmui6r_h5OwTg  40.453845  -79.980478
# 51610  HzUxQ1WpeNmeecXN-HPlPw  45.492610  -73.580954
# 51611  hdNOL59QqvGlg70E4yHrsQ  43.710603  -79.399053
# 51612  9QtHDX71JnaQbmzWWVbi-A  36.137112 -115.152919
#
#                             business_name  \
# 0      South Florida Style Chicken & Ribs
# 1                                 Blimpie
# 2                              Applebee's
# 3                            China Garden
# 4                                 Rocky's
# 5                               Wild Wing
# 6                             Red Lobster
# 7                               The Works
# 8                  Milestones Restaurants
# 9                 Papa Chang's Tea Bistro
# 10                    Quaker Steak & Lube
# 11                   McCarthy's Irish Pub
# 12                         Domino's Pizza
# 13                       Szechuan Cuisine
# 14               Nabers Music, Bar & Eats
# 15                            Oishi Sushi
# 16                              Le Cartet
# 17                        Boardwalk Place
# 18                        Fiesta Ranchera
# 19                          El Pollo Loco
# 20                       Valvona & Crolla
# 21               Baja Fresh Mexican Grill
# 22                              Five Guys
# 23                    Ristorante Beatrice
# 24              Sidewalk Cafe Painesville
# 25       The Great Canadian Pizza Company
# 26                         Steak 'n Shake
# 27               McChans Oriental Express
# 28        Joshan Filipino Oriental Market
# 29                            Jade Palace
# ...                                   ...
# 51583                            Thaïzone
# 51584                    Boom J's Cuisine
# 51585                 OnRoute - King City
# 51586                         Whataburger
# 51587                 American Gypsy Cafe
# 51588                      Tacos El Gordo
# 51589                 Pasquale's Pizzeria
# 51590                New Korea Restaurant
# 51591                       Lehman's Deli
# 51592                          McDonald's
# 51593                         Tim Hortons
# 51594              Winchell's Pub & Grill
# 51595                      Sweet Tomatoes
# 51596                           Jade Star
# 51597                            Stazione
# 51598                     Quickee Burgers
# 51599                  Korean BBQ & Rolls
# 51600                      Stacks Kitchen
# 51601                        Tacos Mexico
# 51602                El Catrin Destileria
# 51603            Hand Car Wash - Sinclair
# 51604           Popeyes Louisiana Kitchen
# 51605                           Pachamama
# 51606                     Ivy League Dogs
# 51607      Nino's Mexican Food Restaurant
# 51608                   Papa John's Pizza
# 51609                        Steve's Deli
# 51610             Bubble Thé Resto-Lounge
# 51611                   Gourmet Burger Co
# 51612            Quark's Bar & Restaurant
#
#                                           address           city state  \
# 0                                  2824 Milton Rd      Charlotte    NC
# 1                                  4719 N 20Th St        Phoenix    AZ
# 2                        9616 E Independence Blvd       Matthews    NC
# 3                                 190 E Dallas Rd        Stanley    NC
# 4                                4759 Liberty Ave     Pittsburgh    PA
# 5                    7070 Saint Barbara Boulevard    Mississauga    ON
# 6                            4502 East Towne Blvd        Madison    WI
# 7                             1794 Liverpool Road      Pickering    ON
# 8                                 30 High Tech Rd  Richmond Hill    ON
# 9                280 W Beaver Creek Road, Unit 30  Richmond Hill    ON
# 10                                2259 Deming Way      Middleton    WI
# 11                          1801 Gerrard Street E        Toronto    ON
# 12                                 25 W Warner Rd       Chandler    AZ
# 13                                  5865 W Ray Rd       Chandler    AZ
# 14                                  825 N 54th St       Chandler    AZ
# 15                               1325 Finch Ave W        Toronto    ON
# 16                                 106 Rue McGill       Montréal    QC
# 17                    1675 Lake Shore Boulevard E        Toronto    ON
# 18                                 1805 S Neil St      Champaign    IL
# 19                          2400 E Lake Mead Blvd      Las Vegas    NV
# 20                                     19 Elm Row      Edinburgh   EDH
# 21                            4190 S Rainbow Blvd      Las Vegas    NV
# 22                        2641 N 44th St, Ste 100        Phoenix    AZ
# 23                      1504 Rue Sherbrooke Ouest       Montreal    QC
# 24                                   1 S State St    Painesville    OH
# 25                           278 Lakeshore Road E    Mississauga    ON
# 26                                 2009 Kenyon Rd         Urbana    IL
# 27                                  Gartloch Road        Glasgow   EDH
# 28                              6325 E Russell Rd      Las Vegas    NV
# 29                         1949 W Ray Rd, Ste 235       Chandler    AZ
# ...                                           ...            ...   ...
# 51583                       6060 Rue Sherbrooke E       Montréal    QC
# 51584                         2026 Rue Wellington       Montréal    QC
# 51585                           12001 Ontario 400        Vaughan    ON
# 51586                          1947 W Broadway Rd           Mesa    AZ
# 51587                   2790 E Flamingo Rd, Ste A      Las Vegas    NV
# 51588                       3049 S Las Vegas Blvd      Las Vegas    NV
# 51589                           6221 Saltsburg Rd     Penn Hills    PA
# 51590                      5661 Steeles Avenue  E        Toronto    ON
# 51591                            24961 Detroit Rd       Westlake    OH
# 51592                               505 N Main St        Belmont    NC
# 51593                             9970 Highway 48        Markham    ON
# 51594                         10620 S Eastern Ave      Henderson    NV
# 51595                        52 East Camelback Rd        Phoenix    AZ
# 51596                      10050 W Bell Rd, Ste 8       Sun City    AZ
# 51597                       820 St-Clair Avenue W        Toronto    ON
# 51598                        4310 E Tropicana Ave      Las Vegas    NV
# 51599                    2702 N Green Valley Pkwy      Henderson    NV
# 51600                             11100 Monroe Rd       Matthews    NC
# 51601                       1800 Las Vegas Blvd S      Las Vegas    NV
# 51602                          18 Tank House Lane        Toronto    ON
# 51603                             5680 S Pecos Rd      Las Vegas    NV
# 51604                   674-676 Sheppard Avenue W        Toronto    ON
# 51605                 1371 Rue Sainte-Catherine E       Montréal    QC
# 51606               15605 W Roosevelt St, Ste 106       Goodyear    AZ
# 51607                             10659 Grand Ave       Sun City    AZ
# 51608                    9335 N Tryon St, Ste 102      Charlotte    NC
# 51609                               2401 Penn Ave     Pittsburgh    PA
# 51610                         1925 St.Catherine W       Montréal    QC
# 51611                           2419 Yonge Street        Toronto    ON
# 51612  Star Trek The Experience, 3000 Paradise Rd      Las Vegas    NV
#
#                                               categories  star_rating  \
# 0      [Food, Soul Food, Convenience Stores, Restaura...          4.5
# 1                              [Sandwiches, Restaurants]          4.5
# 2      [Burgers, Bars, Restaurants, Sports Bars, Nigh...          2.0
# 3                                 [Chinese, Restaurants]          3.0
# 4      [Sandwiches, Restaurants, Italian, Diners, Bre...          3.0
# 5                           [Chicken Wings, Restaurants]          2.5
# 6         [Restaurants, Seafood, American (Traditional)]          3.0
# 7                                 [Burgers, Restaurants]          3.0
# 8      [Comfort Food, Canadian (New), Restaurants, Ba...          2.5
# 9           [Taiwanese, Food, Coffee & Tea, Restaurants]          4.0
# 10     [Burgers, Chicken Wings, Bars, Restaurants, Am...          3.0
# 11           [Pubs, Restaurants, Bars, Irish, Nightlife]          4.0
# 12       [Chicken Wings, Sandwiches, Restaurants, Pizza]          2.5
# 13                                [Restaurants, Chinese]          4.0
# 14                        [Nightlife, Restaurants, Bars]          4.0
# 15               [Asian Fusion, Restaurants, Sushi Bars]          2.0
# 16     [Restaurants, Specialty Food, French, Breakfas...          4.0
# 17     [American (Traditional), Restaurants, Bars, Pu...          3.0
# 18                                [Restaurants, Mexican]          2.0
# 19     [Restaurants, American (Traditional), Mexican,...          3.0
# 20     [Food, Shopping, Grocery, Delis, Gift Shops, C...          4.0
# 21                                [Mexican, Restaurants]          3.5
# 22     [American (New), Burgers, Fast Food, Restaurants]          3.5
# 23                                [Italian, Restaurants]          4.0
# 24     [American (Traditional), Breakfast & Brunch, R...          3.0
# 25                                  [Pizza, Restaurants]          4.0
# 26     [Diners, Breakfast & Brunch, Burgers, American...          2.0
# 27                                [Chinese, Restaurants]          4.0
# 28      [Chinese, Food, Convenience Stores, Restaurants]          3.5
# 29                                [Restaurants, Chinese]          2.5
# ...                                                  ...          ...
# 51583                                [Thai, Restaurants]          1.5
# 51584                           [Restaurants, Caribbean]          4.0
# 51585  [Hotels & Travel, Restaurants, Event Planning ...          3.5
# 51586  [American (Traditional), Burgers, Restaurants,...          3.5
# 51587  [Mediterranean, Persian/Iranian, Restaurants, ...          4.5
# 51588                      [Tacos, Mexican, Restaurants]          4.0
# 51589                      [Restaurants, Italian, Pizza]          4.0
# 51590       [Food Court, Fast Food, Restaurants, Korean]          3.5
# 51591             [Restaurants, Soup, Sandwiches, Delis]          4.0
# 51592                  [Restaurants, Fast Food, Burgers]          2.0
# 51593  [Restaurants, Sandwiches, Coffee & Tea, Breakf...          2.0
# 51594  [Bars, Lounges, American (Traditional), Nightl...          4.0
# 51595    [Restaurants, Buffets, Salad, Soup, Vegetarian]          3.5
# 51596     [Chicken Wings, Chinese, Seafood, Restaurants]          3.5
# 51597             [Italian, Restaurants, Canadian (New)]          3.5
# 51598                  [Burgers, Restaurants, Fast Food]          2.0
# 51599          [Japanese, Barbeque, Restaurants, Korean]          4.5
# 51600            [Breakfast & Brunch, Restaurants, Food]          4.0
# 51601                             [Restaurants, Mexican]          3.0
# 51602         [Mexican, Tapas/Small Plates, Restaurants]          3.5
# 51603  [Gas Stations, Restaurants, Car Wash, Delis, F...          4.5
# 51604  [Restaurants, Chicken Wings, Fast Food, Southe...          2.0
# 51605                           [Restaurants, Argentine]          4.5
# 51606                            [Restaurants, Hot Dogs]          4.0
# 51607                             [Restaurants, Mexican]          3.5
# 51608                               [Pizza, Restaurants]          2.0
# 51609      [Restaurants, Delis, Sandwiches, Food Stands]          4.5
# 51610  [Food, Taiwanese, Restaurants, Coffee & Tea, C...          3.0
# 51611                             [Restaurants, Burgers]          3.0
# 51612                      [American (New), Restaurants]          4.0
#
#        is_open                                               attr
# 0            0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 1            0  {'RestaurantsTableService': False, 'GoodForMea...
# 2            1  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 3            1  {'RestaurantsAttire': 'casual', 'Alcohol': 'no...
# 4            1  {'RestaurantsTableService': True, 'GoodForMeal...
# 5            1  {'HasTV': True, 'RestaurantsGoodForGroups': Tr...
# 6            1  {'RestaurantsTableService': True, 'GoodForMeal...
# 7            1  {'RestaurantsTableService': True, 'GoodForMeal...
# 8            1  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 9            1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 10           1  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 11           0  {'Alcohol': 'full_bar', 'HasTV': True, 'Restau...
# 12           1  {'RestaurantsTableService': False, 'GoodForMea...
# 13           0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 14           0  {'BusinessParking': {'garage': False, 'street'...
# 15           0  {'RestaurantsTableService': True, 'GoodForMeal...
# 16           1  {'RestaurantsTableService': True, 'GoodForMeal...
# 17           1  {'DogsAllowed': True, 'Alcohol': 'full_bar', '...
# 18           0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 19           1  {'RestaurantsTableService': True, 'GoodForMeal...
# 20           1  {'RestaurantsTableService': True, 'GoodForMeal...
# 21           0  {'RestaurantsPriceRange2': 1, 'RestaurantsAtti...
# 22           1  {'RestaurantsTableService': False, 'GoodForMea...
# 23           1  {'RestaurantsTableService': True, 'GoodForMeal...
# 24           1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 25           1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 26           1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 27           1  {'Alcohol': 'none', 'RestaurantsReservations':...
# 28           1  {'BusinessAcceptsCreditCards': True, 'Restaura...
# 29           1  {'RestaurantsAttire': 'casual', 'OutdoorSeatin...
# ...        ...                                                ...
# 51583        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51584        1  {'RestaurantsTableService': False, 'GoodForMea...
# 51585        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51586        1  {'RestaurantsTableService': True, 'GoodForMeal...
# 51587        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51588        1  {'RestaurantsTableService': False, 'GoodForMea...
# 51589        1  {'RestaurantsAttire': 'casual', 'GoodForKids':...
# 51590        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51591        1  {'RestaurantsTableService': False, 'GoodForMea...
# 51592        1  {'RestaurantsTableService': False, 'GoodForMea...
# 51593        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51594        1  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 51595        0  {'RestaurantsTableService': False, 'GoodForMea...
# 51596        1  {'BusinessParking': {'garage': False, 'street'...
# 51597        1  {'BusinessParking': {'garage': False, 'street'...
# 51598        0  {'GoodForKids': True, 'RestaurantsReservations...
# 51599        0  {'RestaurantsTableService': True, 'GoodForMeal...
# 51600        1  {'RestaurantsTableService': True, 'GoodForMeal...
# 51601        1  {'RestaurantsTableService': False, 'GoodForMea...
# 51602        1  {'RestaurantsTableService': True, 'GoodForMeal...
# 51603        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51604        1  {'GoodForKids': True, 'WiFi': 'free', 'Restaur...
# 51605        1  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51606        0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51607        1  {'RestaurantsTableService': True, 'GoodForMeal...
# 51608        1  {'RestaurantsTableService': False, 'HasTV': Fa...
# 51609        0  {'RestaurantsTableService': False, 'GoodForMea...
# 51610        0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51611        0  {'GoodForMeal': {'dessert': False, 'latenight'...
# 51612        0  {'GoodForMeal': {'dessert': False, 'latenight'...
#
# [51613 rows x 11 columns]

# %%
business=business[business["is_open"]==1]  #Filter out the closed restaurants

# %%
del business['is_open']

# %% [markdown]
# <h4> Categorizing Restaurants into 10 major cuisines</h4>

# %%
# Finding the Cuisine of the Restaurants
def rest_category(inp):
    for var in inp:
        if('Mexican' in var):
            return 'Mexican'
        elif('Italian' in var):
            return 'Italian'
        elif('Japanese' in var):
            return 'Japanese'
        elif('Thai' in var):
            return 'Thai'
        elif('Indian' in var):
            return 'Indian'
        elif('Greek' in var):
            return 'Greek'
        elif('French' in var):
            return 'French'
        elif('Spanish' in var):
            return 'Spanish'
        elif('Mediterranean' in var):
            return 'Mediterranean'
        else:
            return 'Other'

# %% [markdown]
# <h4>Choosing only Restaurants in the Yelp data </h4>

# %%
temp_data=business
#Getting list of different business id
bus_id_list = []
bus_id = set(temp_data.business_id)
bus_id = list(bus_id)
#For each business, checking if attributes have restaurant in them and making a list
#of businesses that have restaurant in their attributes
for bus in bus_id:
    bus_data = temp_data.loc[temp_data.business_id == bus]
    attr_list = list(bus_data.attr)[0]
    keys = list(attr_list.keys())
    attr_keys = '-'.join(keys)
    if('Restaurant' in attr_keys):
        bus_id_list.append(bus)
    elif('restaurant' in attr_keys):
        bus_id_list.append(bus)

#Defining a column to check if business is restaurant
temp_data['is_rest'] = 0

#If business is restaurant set this column to 1
temp_data.loc[temp_data['business_id'].isin(bus_id_list),'is_rest'] = 1


#Create new dataframe with data of only restaurants
rest_data = temp_data.loc[temp_data['is_rest'] == 1]
#Resetting index of the new dataframe
rest_data = rest_data.reset_index(drop = True)
# Out:
# /Users/mansisheth/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/mansisheth/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rest_data.head()
# Out:
#               business_id        lat       long business_name  \
# 0  SDMRxmcKPNt1AHPBKqO64Q  35.135196 -80.714683    Applebee's
# 1  iFEiMJoEqyB9O8OUNSdLzA  35.355085 -81.087268  China Garden
# 2  HmI9nhgOkrXlUr6KZGZZew  40.461350 -79.948113       Rocky's
# 3  qnpvw-uQyRn9nlClWFK9aA  43.639236 -79.716199     Wild Wing
# 4  TXiEgINSZ75d3EtvLvkc4Q  43.128034 -89.307157   Red Lobster
#
#                         address         city state  \
# 0      9616 E Independence Blvd     Matthews    NC
# 1               190 E Dallas Rd      Stanley    NC
# 2              4759 Liberty Ave   Pittsburgh    PA
# 3  7070 Saint Barbara Boulevard  Mississauga    ON
# 4          4502 East Towne Blvd      Madison    WI
#
#                                           categories  star_rating  \
# 0  [Burgers, Bars, Restaurants, Sports Bars, Nigh...          2.0
# 1                             [Chinese, Restaurants]          3.0
# 2  [Sandwiches, Restaurants, Italian, Diners, Bre...          3.0
# 3                       [Chicken Wings, Restaurants]          2.5
# 4     [Restaurants, Seafood, American (Traditional)]          3.0
#
#                                                 attr  is_rest
# 0  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...        1
# 1  {'RestaurantsAttire': 'casual', 'Alcohol': 'no...        1
# 2  {'RestaurantsTableService': True, 'GoodForMeal...        1
# 3  {'HasTV': True, 'RestaurantsGoodForGroups': Tr...        1
# 4  {'RestaurantsTableService': True, 'GoodForMeal...        1

# %%
rest_data['cuisine']=rest_data.apply(lambda x: rest_category(x['categories']),axis=1)

# %%
rest_data_map = rest_data[['business_name','cuisine','lat','long','city','state']]

rest_data_map.to_csv('restaurant.csv') #to crete a map of which cuisine is present in which region

# %%
rating_data=rest_data.groupby( [ "state", "city"] )['star_rating'].mean()
rating_data.to_csv('region_rating.csv')

# %%
datafile='review.json'
review_id = []
user_id=[]
business_id=[]
stars=[]
date=[]
text=[]
count=0
with open(datafile,'r') as f:
    for line in f:
        if(count>=100000):
            break
        count+=1
        data = json.loads(line)
        review_id.append(data.get('review_id'))
        user_id.append(data.get('user_id'))
        business_id.append(data.get('business_id'))
        stars.append(data.get('stars'))
        date.append(data.get('date'))
        text.append(data.get('text'))

# %%
rating_data=rest_data.groupby( [ "state", "city"] )['star_rating'].mean()
rating_data.to_csv('region_rating.csv')

# %%
review=pd.DataFrame.from_items([('review_id',review_id),('user_id',user_id),('business_id',business_id),('stars',stars),('date',date),('text',text)])

# %%
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  VfBHSwC5Vz_pbFluy07i9Q  cjpdDjZyprfyDG3RlkVG3w  uYHaNptLzDLoV_JZ_MuzUA
# 1  3zRpneRKDsOPq92tq7ybAA  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2  ne5WhI1jUFOcRn-b-gAzHA  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 3  llmdwOgDReucVoWEry61Lw  oU2SSOmsp_A8JYI7Z2JJ5w  uYHaNptLzDLoV_JZ_MuzUA
# 4  DuffS87NaSMDmIfluvT83g  0xtbPEna2Kei11vsU-U2Mw  uYHaNptLzDLoV_JZ_MuzUA
#
#    stars        date                                               text
# 0      5  2016-07-12  My girlfriend and I stayed here for 3 nights a...
# 1      3  2016-10-02  If you need an inexpensive place to stay for a...
# 2      3  2015-09-17  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 3      4  2016-08-21  Location is everything and this hotel has it! ...
# 4      5  2013-11-20  gute lage im stadtzentrum. shoppingmeile und s...

# %%
rest_and_reviews=rest_data.join(review.set_index('business_id'), on='business_id')
rest_and_reviews.head()

# %%
rest_data_reviews=rest_and_reviews.loc[rest_and_reviews.text.notnull()]

# %%
p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'

# %% [markdown]
# <h4> Making a list of positive and negative words </h4>

# %%
def get_pos_neg_words():
    def get_words(url):
        import requests
        words = requests.get(url).content.decode('latin-1')
        word_list = words.split('\n')
        index = 0
        while index < len(word_list):
            word = word_list[index]
            if ';' in word or not word:
                word_list.pop(index)
            else:
                index+=1
        return word_list

    #Get lists of positive and negative words
    p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
    n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
    positive_words = get_words(p_url)
    negative_words = get_words(n_url)
    return positive_words,negative_words

positive_words,negative_words = get_pos_neg_words()

# %%
def remove_punctuation(word):
    if word and ((word[-1] >= 'a' and word[-1]<='z') or (word[-1] >= 'A' and word[-1]<='Z')):
        return word
    elif word:
        return word[:-1]
    else:
        return word

# %%
rest_data_reviews

# %%
import plotly 
plotly.tools.set_credentials_file(username='divas781993', api_key='yI2dBsUQfwRuqkgC2N1D')

# %% [markdown]
# <h4> Visualizing average footfall and average rating by day of the week in a given state </h4>

# %%
def state_footfall(state):
    state_data = rest_data_reviews.loc[rest_data_reviews["state"] == state]
    
    footfall = [0,0,0,0,0,0,0]
    rating = [0,0,0,0,0,0,0]
    state_dates = state_data['date'].tolist()
    state_days = [datetime.datetime.strptime(date,'%Y-%m-%d').weekday() for date in state_dates]
    state_stars = state_data['stars'].tolist()

    for i in range(len(state_days)):
        j = state_days[i]
        footfall[j%7] += 1
        rating[j%7] += state_stars[i]
    
    rating = [x/y for x,y in zip(rating,footfall)]

    import matplotlib.pyplot as plt; plt.rcdefaults()
    import numpy as np
    import matplotlib.pyplot as plt
     
    objects = ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')
    y_pos = np.arange(len(objects))
    performance = rating
 
    plt.bar(y_pos, performance, align='center', alpha=1.0)
    plt.xticks(y_pos, objects)
    plt.ylabel('Average Star Rating')
    plt.title('Day of the Week')
 
    plt.show()
    
    objects = ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')
    y_pos = np.arange(len(objects))
    performance = footfall
 
    plt.bar(y_pos, performance, align='center', alpha=1.0)
    plt.xticks(y_pos, objects)
    plt.ylabel('Number of Reviews')
    plt.title('Day of the Week')
 
    plt.show()

# %%
state_footfall('OH')

# %%
lat = list(rest_data["lat"])
long = list(rest_data["long"])

# %%
grouped_data = business.groupby("state")
size = list(grouped_data.size())
states = list(grouped_data.groups.keys())
lat = list(grouped_data['lat'].mean())
long = list(grouped_data['long'].mean())
loc = [(latitude,longitude) for latitude,longitude in zip(lat,long)]

# %% [markdown]
# <h4> Plotting a heatmap for number of restaurants in the given data </h4>

# %%
import plotly.plotly as py
import pandas as pd

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = states,
        z = size,
        locationmode = 'USA-states',
        text = states,
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Restaurant heat map")
        ) ]

layout = dict(
        title = 'Number of restaurants in various states',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )

# %% [markdown]
# <h4> Analyzing reviews using POS tagging to extract the relvant words for recommendation </h4>

# %%
def analyze_review(review, qualities):
    
    import nltk
    
    review_sentences = nltk.sent_tokenize(review)
    for sentence in review_sentences:
    
        temp_qualities = []
        count = 0
        quality = ""
        
        words = nltk.word_tokenize(sentence)
        words = [word.lower() for word in words]
        words = [word for word in words if word not in ('the','food','i','place','restaurant','meal','aquarium')]
        tags = nltk.pos_tag(words)
        
        for i in range(len(tags)):
            
            #current element stored
            tup = tags[i]
            prev_tup = tags[i-1]
            
            #increasing/decreasing the count according to the positive/negative value of adjective
            if(tup[1] == "JJ"):
            
                if(tup[0] in positive_words and prev_tup[0] != 'not'):
                    count += 1
                elif(tup[0] in negative_words and prev_tup[0] != 'not'):
                    count -= 1
                elif(tup[0] in positive_words and prev_tup[0] == 'not'):
                    count -= 1
                elif(tup[0] in negative_words and prev_tup[0] == 'not'):
                    count += 1
        
        for i in range(len(tags)):
            
            #current element stored
            tup = tags[i]
        
            #next element stored
            if(i < len(tags)-1):
                tup_next = tags[i+1]
            else:
                tup_next = ("Z","Z")
            
            #incrementing count for the noun associated with current count
            if(tup[1] == "NN"):
                
                quality = quality + tup[0]
                
                #checking if dish name is more than a word
                if(tup_next[1] != "NN"):
                    if(quality not in temp_qualities):
                        temp_qualities.append(quality)
                        quality = ""
                else:
                    quality = quality + " "
                    
        #Updating dictionary of qualities
        if (count != 0):
            for qual in temp_qualities:
                if(qual in qualities):
                    qualities[qual] += count
                else:
                    qualities[qual] = count

# %%
def for_rest_rev(reviews):
    
    qualities = dict({})
    
    for review in reviews:
        analyze_review(review,qualities)
    
    return(qualities)

# %%
rest_data=rest_data_reviews
rest_data.head()

# %%
bus_id_set = set(rest_data["business_name"])
id_qualities = dict({})

for each_id in bus_id_set:
    reviews = rest_data.loc[rest_data["business_name"] == each_id ,"text"]
    q = for_rest_rev(reviews)
    id_qualities[each_id] = q

# %%
def search(food,city):
    from collections import Counter
    food_final = dict({})
    
    for key,value in id_qualities.items():
        city_1 = business.loc[business["business_name"] == key, "city"]
        if city == city_1.iloc[0]:
            if food in value.keys():
                food_final[key] = value[food]
    
    food_reviews = dict(Counter(food_final).most_common(5)).keys()
    return food_reviews

# %% [markdown]
# <h4> Using the analysis above, selecting top five restaurants for a given food item and location </h4>

# %%
top_five = list(search("beer","Las Vegas"))
top_five

# %% [markdown]
# <h4> The monthly average rating trend for these restaurants </h4>

# %%
#Plotting the rating trend
import plotly.plotly as py
import plotly.graph_objs as go


rest1=rest_data[rest_data['business_name']==top_five[0]] 
rest1['Year-Month']=rest1.apply(lambda x: x['date'][0:4]+' '+x['date'][5:7],axis=1)
rating_trend1=rest1.groupby(['Year-Month'])['stars'].mean()



dates_list = [datetime.datetime.strptime(date, '%Y %m').date() for date in rating_trend1.index]
trace1 = go.Scatter(
    x = dates_list,
    y = rating_trend1.values
)
data1 = [trace1]
py.iplot(data1, filename='basic-line')

# %%
rest2=rest_data_reviews[rest_data['business_name']==top_five[1]] 
rest2['Year-Month']=rest2.apply(lambda x: x['date'][0:4]+' '+x['date'][5:7],axis=1)
rating_trend2=rest2.groupby(['Year-Month'])['stars'].mean()
dates_list = [datetime.datetime.strptime(date, '%Y %m').date() for date in rating_trend2.index]
trace2 = go.Scatter(
    x = dates_list,
    y = rating_trend2.values
)
data2 = [trace2]
py.iplot(data2, filename='basic-line')

# %%
rest3=rest_data_reviews[rest_data['business_name']==top_five[2]] 
rest3['Year-Month']=rest3.apply(lambda x: x['date'][0:4]+' '+x['date'][5:7],axis=1)
rating_trend3=rest3.groupby(['Year-Month'])['stars'].mean()
dates_list = [datetime.datetime.strptime(date, '%Y %m').date() for date in rating_trend3.index]
trace3 = go.Scatter(
    x = dates_list,
    y = rating_trend3.values
)
data3 = [trace3]
py.iplot(data3, filename='basic-line')

# %%
rest4=rest_data_reviews[rest_data['business_name']==top_five[3]] 
rest4['Year-Month']=rest4.apply(lambda x: x['date'][0:4]+' '+x['date'][5:7],axis=1)
rating_trend4=rest4.groupby(['Year-Month'])['stars'].mean()
dates_list = [datetime.datetime.strptime(date, '%Y %m').date() for date in rating_trend4.index]
trace4 = go.Scatter(
    x = dates_list,
    y = rating_trend4.values
)
data4 = [trace4]
py.iplot(data4, filename='basic-line')

# %%
rest5=rest_data_reviews[rest_data['business_name']==top_five[4]] 
rest5['Year-Month']=rest5.apply(lambda x: x['date'][0:4]+' '+x['date'][5:7],axis=1)
rating_trend5=rest5.groupby(['Year-Month'])['stars'].mean()
dates_list = [datetime.datetime.strptime(date, '%Y %m').date() for date in rating_trend5.index]
trace5 = go.Scatter(
    x = dates_list,
    y = rating_trend5.values
)

data5 = [trace4]
py.iplot(data4, filename='basic-line')

# %%
for name in top_five:
    
    # datetime.datetime.strptime(data.get('yelping_since').strip(),"%Y-%m").date()
    test_rest=rest_data[rest_data['business_name']==name] 
    test_rest=test_rest.sort_values('stars',ascending=False)

    #Getting top 5 reviews To understand the good things people have been saying lately about it
    no_of_reviews=10
    pos_text=[]
    for i in range(no_of_reviews):
        pos_text.append(test_rest.iloc[i]['text'])
    pos_text=' '.join(pos_text)
    
    from nltk.tokenize import word_tokenize
    pos_words=word_tokenize(pos_text)
    
    #Tring to remove punctuation and filter out the text
    pos_words_filtered=[]
    min_length=3
    DELETE_WORDS = []
    for words in pos_words:
        word = remove_punctuation(words)
        if (word and len(word)> min_length and (not(word in DELETE_WORDS)) ):
            pos_words_filtered.append(word)

    text=' '.join(pos_words_filtered)
    
    from wordcloud import WordCloud, STOPWORDS
    import matplotlib.pyplot as plt
    # %matplotlib inline

    wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',width=3000,height=3000).generate(text)
    plt.imshow(wordcloud)
    plt.axis('off')
    print(name)
    plt.show()

# %%
def fav_food(state):
    
    state_foods = dict({})
    key_1 = business.loc[business["state"] == state, "business_name"]
    
    for key,value in id_qualities.items():
        if key in list(key_1):
                for key,value in value.items():
                    if key in state_foods.keys():
                        state_foods[key] += value
                    else:
                        state_foods[key] = value
    
    fav_food = dict(Counter(state_foods).most_common(10)).keys()
    return fav_food

# %%
states_fav_food = fav_food("NC")
states_fav_food

# %% [markdown]
# <h4> Predicting positive or negative sentiment of a review </h4>

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
def vader_comparison(texts):
    analyzer = SentimentIntensityAnalyzer()
    sentences = sent_tokenize(texts)
    pos=compound=neu=neg=0
    num_sentences = len(sentences)
    for sentence in sentences:
        vs = analyzer.polarity_scores(sentence)
        pos+=vs['pos']/num_sentences
        compound+=vs['compound']/num_sentences
        neu+=vs['neu']/num_sentences
        neg+=vs['neg']/num_sentences
    result=(pos,compound,neu,neg)
    return result

# %%
def confusion_matrix(predicted, actual):
    if len(predicted) != len(actual): return -1
    tp = 0.0
    fp = 0.0
    tn = 0.0
    fn = 0.0
    for i in range(len(actual)):
        if actual[i] == 1 : #labels that are 1.0  (positive examples)
            if predicted[i] == 1:
                tp += 1.0 #correctly predicted positive
            else:
                fn += 1.0 #incorrectly predicted negative
        else:              #labels that are 0.0 (negative examples)
            if predicted[i] == 0 :
                tn += 1.0 #correctly predicted negative
            else:
                fp += 1.0 #incorrectly predicted positive
    rtn = [tp, fp, tn, fn]

    return rtn

# %%
# Predicting the sentiment using Vander 
def naive_sentiment(rating):
    if rating <3:
        return 0
    else :
        return 1

review_train=review[0:1000]
review_test=review[0:250]

review_train['sentiment']=review_train.apply(lambda x:  naive_sentiment(x['stars']) , axis=1)
review_test['sentiment']=review_test.apply(lambda x:  naive_sentiment(x['stars']) , axis=1)

review_train['sentiment']=review_train.apply(lambda x:  naive_sentiment(x['stars']) , axis=1)
review_test['sentiment']=review_test.apply(lambda x:  naive_sentiment(x['stars']) , axis=1)

review_train['positive_percentage_review']=review_train.apply(lambda x:  vader_comparison(x['text'])[0]*100 , axis=1)
review_test['positive_percentage_review']=review_test.apply(lambda x:  vader_comparison(x['text'])[0]*100 , axis=1)

lower_sentiment=min(review_train['positive_percentage_review'])
upper_sentiment=max(review_train['positive_percentage_review'])
step=(upper_sentiment-lower_sentiment)/100
sentiment_threshold=np.arange(lower_sentiment,upper_sentiment,step)

best_thresh=100
min_error=len(review_train)
n=len(review_train)
errors=[]
for i in range(len(sentiment_threshold)):
    x=review_train['positive_percentage_review']>sentiment_threshold[i]
    acc=sum(x==review_train['sentiment'])
    error=len(review_train)-acc
    errors.append((error/n)*100)
    if(error<min_error):
        min_error=error
        best_thresh=sentiment_threshold[i]
        
accuracy=(100-min(errors))
print("The accuracy of the model on the train data is ",accuracy,"%")

predicted=review_train['positive_percentage_review']>best_thresh
tp,fp,tn,fn=confusion_matrix(predicted,review_train['sentiment'])

print("True positive, False positive, True negative, False Negative are ",tp," ",fp," ",tn," ",fn)


x=review_test['positive_percentage_review']>best_thresh
accuracy=((sum(x==review_test['sentiment']))/(len(review_test)))*100
print("The accurcy of test data is ",accuracy,"%")

# %% [markdown]
# <h4> Plot for the error of the predictive model for different threshold values </h4>

# %%
import plotly.plotly as py
import plotly.graph_objs as go
#Plot for the accuracy of the Algorithm for different values of the threshold 
trace = go.Scatter(
    x = sentiment_threshold,
    y = errors,
    name = 'Error %'
)

data = [trace]
py.iplot(data, filename='basic-line')

# %% [markdown]
# <h4> Predicting the ratings using SVM </h4>

# %%
# Predicting rating using SVM
datafile='review.json'
stars=[]
text=[]
count=0
with open(datafile,'r') as f:
    for line in f:
        if(count>=1000):
            break
        count+=1
        data = json.loads(line)
        stars.append(data.get('stars'))
        text.append(data.get('text'))

from collections import Counter
def balance_classes(x_inp, y_inp):
    frequency = Counter(y_inp)
    maximum_possible = frequency.most_common()[-1][1]
    number_added = {clss: 0 for clss in frequency.keys()}
    yout=[]
    xout=[]
    for i, y in enumerate(y_inp):
        if number_added[y] < maximum_possible:
            yout.append(y)
            xout.append(x_inp[i])
            number_added[y]+= 1
    return xout, yout

balanced_x, balanced_y = balance_classes(text, stars)

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))
vectors = vectorizer.fit_transform(balanced_x)

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(vectors, balanced_y, test_size=0.33, random_state=42)

from sklearn.svm import LinearSVC
classifier = LinearSVC()
classifier.fit(X_train,Y_train)

prediction=classifier.predict(X_test)

from sklearn.metrics import accuracy_score
print("SVM accuracy in predicting the rating of a review on test data is ",accuracy_score(Y_test,prediction)*100,"%")

from sklearn.metrics import confusion_matrix
print("The confusion matrix on test data is \n",confusion_matrix(Y_test,prediction))

# %%
#Predicting sentiment using SVM
sent=[]
for i in range(len(stars)):
    if(stars[i]<3):
        predict=0
        sent.append(predict)
    else:
        predict=1
        sent.append(predict)
        
balanced_x, balanced_y = balance_classes(text, sent)
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))
vectors = vectorizer.fit_transform(balanced_x)
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(vectors, balanced_y, test_size=0.25, random_state=42)
from sklearn.svm import LinearSVC
classifier = LinearSVC()
classifier.fit(X_train,Y_train)
prediction=classifier.predict(X_test)
from sklearn.metrics import accuracy_score
print("SVM accuracy in predicting the sentiment of a review on test data is ",accuracy_score(Y_test,prediction)*100,"%")

from sklearn.metrics import confusion_matrix
print("The confusion matrix is \n",confusion_matrix(Y_test,prediction))
